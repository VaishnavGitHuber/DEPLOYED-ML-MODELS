# %% [markdown]
# ### AUTHOR : VAISHNAV KRISHNA P
# #### INTERNSHIP: INTERN PE
# * TASK: Task : Make a CAR PRICE Predictor with ML
# * After that make a separate Video on it and post On LinkedIn.And Tag Internpe
# * This Below Video is for your reference only.
# * You can show your skills style in your own way DeadLine is End of this week

# %%
# Loading the necessory dependednies 
import pandas as pd
import seaborn as sns 
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# ignoring the warnings 
import warnings
warnings.filterwarnings(action="ignore")

# for checking the skewness and kurtosis 
from scipy.stats import skew,kurtosis

# Print options setting
pd.set_option("display.max_rows",None)
pd.set_option("display.max_columns",None)

# label encoder for feature encoding
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler,Normalizer,MinMaxScaler

# for splitting
from sklearn.model_selection import train_test_split,KFold,cross_val_score

# Training model 
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor

# for evaluation of the model
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

# importing the file for pickling 
import pickle

# %%
# Loading the dataset 
df = pd.read_csv("quikr_car.csv")
data = df.copy()

# %%
# First 5 records 
df.head()
# Out:
#                                      name   company  year          Price  \
# 0    Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007         80,000
# 1                 Mahindra Jeep CL550 MDI  Mahindra  2006       4,25,000
# 2              Maruti Suzuki Alto 800 Vxi    Maruti  2018  Ask For Price
# 3  Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014       3,25,000
# 4        Ford EcoSport Titanium 1.5L TDCi      Ford  2014       5,75,000
#
#    kms_driven fuel_type
# 0  45,000 kms    Petrol
# 1      40 kms    Diesel
# 2  22,000 kms    Petrol
# 3  28,000 kms    Petrol
# 4  36,000 kms    Diesel

# %%
# Shape of the dataset 
df.shape
# Out:
# (892, 6)

# %%
# Information reageding the dataset 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 892 entries, 0 to 891
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        892 non-null    object
#  1   company     892 non-null    object
#  2   year        892 non-null    object
#  3   Price       892 non-null    object
#  4   kms_driven  840 non-null    object
#  5   fuel_type   837 non-null    object
# dtypes: object(6)
# memory usage: 41.9+ KB

# %% [markdown]
# * All the records are in the form of Object
# * Consists of 5 features and 892 recods

# %% [markdown]
# ### EDA
# 1. Misssing Value analysis
# 2. Continous and Categorial feature
# 3. Feature Distribution
# 4. Corelation analysis
# 5. Outlier Analysis
# 6. Data Visualisation
# 7. Data Cleaning
# 8. SKEWNESS AND KURTOSIS OF EACH CONTINOUS FEATURE

# %% [markdown]
# ### MISSING VALUE ANALYSIS

# %%
# Missing Value analysis using heat map 
plt.title("MIssing Value Analysis")
sns.heatmap(df.isnull(),cbar=False)
plt.show()

# %%
# Missing value percent using lineplot 
(100 * df.isnull().sum()/len(df)).plot(marker="s",grid=True)
plt.title("PERCENT OF MISSING")
plt.ylabel("Percent")
plt.show()

# %%
df.isnull().sum()
# Out:
# name           0
# company        0
# year           0
# Price          0
# kms_driven    52
# fuel_type     55
# dtype: int64

# %% [markdown]
# * kms driven have 52 missing value and fuel type has 55 missing value.rest features are clean. Missing value handling will take care in later on stage

# %% [markdown]
# #### NO OF UNIQUE VALUES IN EACH FEATURE

# %%
df.nunique().plot(kind="bar",color="b",edgecolor="k",title="No of unique values",grid=True)
plt.show()

# %%
df.nunique()
# Out:
# name          525
# company        48
# year           61
# Price         274
# kms_driven    258
# fuel_type       3
# dtype: int64

# %% [markdown]
# ### CATEGORICAL AND NUMERICAL FEATURES

# %%
# Splitting categorical and continous features 
categorical_features = []
continous_features = []

for feature in df.columns:
    if df[feature].nunique() > 70:
        continous_features.append(feature)
    else:
        categorical_features.append(feature)

# %%
# Printing the information
print("CATEGORICAL FEATURES ARE : ",categorical_features)
print("CONTINOUS FEATURES ARE: ",continous_features)
print("NO OF CATEGORICAL FEATURES: ",len(categorical_features))
print("NO OF CONTINOUS FEATURES: ",len(continous_features))
# Out:
# CATEGORICAL FEATURES ARE :  ['company', 'year', 'fuel_type']
# CONTINOUS FEATURES ARE:  ['name', 'Price', 'kms_driven']
# NO OF CATEGORICAL FEATURES:  3
# NO OF CONTINOUS FEATURES:  3

# %%
# Value counts of fuel type 
df["fuel_type"].value_counts()
# Out:
# Petrol    440
# Diesel    395
# LPG         2
# Name: fuel_type, dtype: int64

# %% [markdown]
# ### DATA CLEANING

# %% [markdown]
# #### CLEANING OF PRICE FEATURE

# %%
# removal of commas from the price feature 
df["Price"] = df["Price"].str.replace(",","")

# %%
# Replacing the Ask for price value of the target feature with the median value 
df["Price"][df["Price"] == "Ask For Price"] = df["Price"][df["Price"] != "Ask For Price"].astype("float").median()

# %%
df["Price"] = df["Price"].astype("float")

# %%
df["Price"].dtype
# Out:
# dtype('float64')

# %% [markdown]
# * So, the price feature is now cleaned

# %% [markdown]
# #### CLEANING KMS DRIVEN FEATURE

# %%
# removing the kms,comma,and noise from the value 
df["kms_driven"] = df["kms_driven"].str.replace("kms","")
df["kms_driven"] = df["kms_driven"].str.replace(",","")
df["kms_driven"] = df["kms_driven"].str.replace("Petrol","45000")

# %%
# casting into float datatype
df["kms_driven"] = df["kms_driven"].astype("float64")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 892 entries, 0 to 891
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        892 non-null    object
#  1   company     892 non-null    object
#  2   year        892 non-null    object
#  3   Price       892 non-null    float64
#  4   kms_driven  840 non-null    float64
#  5   fuel_type   837 non-null    object
# dtypes: float64(2), object(4)
# memory usage: 41.9+ KB

# %%
# Handling the missing values
df["kms_driven"].fillna(df["kms_driven"].median(),inplace=True)

# %%
df["kms_driven"].isnull().sum()
# Out:
# 0

# %%
df["kms_driven"].dtype
# Out:
# dtype('float64')

# %% [markdown]
# * So, the kms_driven column is now cleaned

# %% [markdown]
# #### CLEANING THE FUEL TYPE FEATURE

# %%
df["fuel_type"].value_counts()
# Out:
# Petrol    440
# Diesel    395
# LPG         2
# Name: fuel_type, dtype: int64

# %%
# Handling the missing value by adding gloabl constant for fuel type 
df["fuel_type"].fillna("Unknown",inplace=True)

# %% [markdown]
# * So, Now dataset is cleaned

# %%
# Noises in the year feature 
noise_year = list(df["year"].value_counts().index[20:])

# %% [markdown]
# * List of noises in the year feature
# * since the most frequent year is 2014 lets replace with 2014

# %% [markdown]
# #### CLEANING THE YEAR FEATURE

# %%
# Removing the noises
for i in range(len(df)):
    if df["year"].iloc[i] in noise_year:
        df["year"].iloc[i] = "2014"

# %%
df["year"].value_counts()
# Out:
# 2014    146
# 2015    117
# 2013     94
# 2016     76
# 2012     75
# 2011     60
# 2009     56
# 2017     56
# 2010     44
# 2018     34
# 2006     22
# 2019     22
# 2007     19
# 2008     16
# 2005     13
# 2003     13
# 2004     12
# 2000      7
# 2002      5
# 2001      5
# Name: year, dtype: int64

# %%
# Type casting to int 
df["year"] = df["year"].astype(int)

# %% [markdown]
# * Age feature all the noises are cleared

# %% [markdown]
# #### CLEANING THE COMPANY FEATURE

# %%
df['company'].value_counts()
# Out:
# Maruti        235
# Hyundai       145
# Mahindra      100
# Tata           74
# Honda          61
# Toyota         39
# Chevrolet      35
# Renault        34
# Ford           31
# Volkswagen     20
# Skoda          13
# Audi           11
# Datsun          8
# Mini            8
# BMW             8
# Nissan          6
# Commercial      6
# Mercedes        6
# Mitsubishi      6
# Force           4
# Fiat            4
# tata            3
# Hindustan       3
# I               3
# MARUTI          2
# urgent          2
# Used            2
# Jaguar          2
# Sale            2
# Well            1
# Any             1
# TATA            1
# sell            1
# scratch         1
# 9               1
# 7               1
# all             1
# Land            1
# 2012            1
# i               1
# Volvo           1
# very            1
# Jeep            1
# Swift           1
# URJENT          1
# selling         1
# Yamaha          1
# Tara            1
# Name: company, dtype: int64

# %%
# Noises in the company feature 
noise_company = ["urgent","Used",'Well','Any','sell','Sale','Well','scratch',"very",'9','7','all','2012','i','I','swift','URJENT','selling']

# %%
# Removing the noises 
for i in range(len(df)):
    if df["company"].iloc[i] in noise_company:
        df["company"].iloc[i] = "Noise"

# %%
# Since the Maruti and MARUTTI is same lets make it unique 
df["company"][df["company"] == "MARUTI"] = "Maruti"

# %%
df["company"].nunique()
# Out:
# 32

# %% [markdown]
# * So, company feature has be cleaned

# %% [markdown]
# ### DISTRIBUTION OF THE DATASET FEATURES USING VISUALISATION

# %% [markdown]
# #### BAR PLOT FOR CATEGORICAL FEATURES

# %%
# BAR plot 
plt.suptitle("CATEGORICAL FEATURES")
c = 1

for feature in categorical_features:
    plt.subplot(1,3,c)
    c += 1
    df[feature].value_counts()[:10].plot(kind="bar",color="r",title=f"{feature}")
    plt.xticks(rotation=90)
plt.tight_layout()  
plt.show()

# %% [markdown]
# #### Scatter plot for price and kilometer driven

# %%
# Scatter plot for price and kilometer driven 
plt.figure(figsize=(10,6))
plt.scatter(x="kms_driven",y="Price",data=df,marker="s",color="r",alpha=0.25)
plt.ylim(0,2e6)
plt.title("SCATTER PLOT: KILOMETER DRIVEN VS PRICE")
plt.xlabel("Kms Driven")
plt.ylabel("PRice")
plt.xlim(0,250000)
plt.show()

# %%
df["Price"].corr(df["kms_driven"])
# Out:
# -0.11379302549418946

# %% [markdown]
# * From scatter plot it is understandable that if the kilometer of driven is less then the price is more

# %% [markdown]
# #### Price vs company boxplot

# %%
# Price vs company boxplot
plt.figure(figsize=(10,6))
sns.boxplot(x="company",y="Price",data=df,saturation=0.50)
plt.title("BOX PLOT: PRICE VS COMPANY")
plt.xticks(rotation=90)
plt.ylim(0e6,4e6)
plt.show()

# %% [markdown]
# * There are some comapnies there vehicles are very expensive

# %% [markdown]
# #### HISTOGRAM OF CONTINOUS FEATURES

# %%
# Histogram of continous features
plt.suptitle("HISTOGRAM: CONTINOUS FEATURES")
c = 1
for feature in ["Price","kms_driven"]:
    plt.subplot(1,2,c)
    c += 1
    df[feature].plot(kind="hist",bins=50,color="b",edgecolor="k",title=f"{feature}")
    plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# * Most of the Vehicles have the price ranges from 0-1L

# %% [markdown]
# #### SKEWNESS AND KURTOSIS OF CONTINOUS FEATURE

# %%
# checking the skwness and Kurtosis
for feature in continous_features:
    if feature not in ["name"]:
        print(f"{feature} -> skewness {skew(df[feature])} -> kurtosis: {kurtosis(df[feature])}")
# Out:
# Price -> skewness 7.800258674926247 -> kurtosis: 114.49843892987421
# kms_driven -> skewness 2.723652360025762 -> kurtosis: 17.13793685233927

# %% [markdown]
# * so, the feature is positively skewed we have to apply some powerful transformation techniques for reducing the skewness

# %% [markdown]
# #### VIOLIN PLOT : FUEL TYPE VS PRICE

# %%
sns.violinplot(x="fuel_type",y="Price",data=df,width=0.9)
plt.title("VIOLIN PLOT: FUEL TYPE VS PRICE")
plt.show()

# %%
df["fuel_type"][df["company"] == "Audi"].value_counts()
# Out:
# Diesel    7
# Petrol    4
# Name: fuel_type, dtype: int64

# %%
df["fuel_type"][df["company"] == "BMW"].value_counts()
# Out:
# Diesel    5
# Petrol    3
# Name: fuel_type, dtype: int64

# %% [markdown]
# * from the violin plot we understood,Diesel vehicles have high price as compared to petrol.May be most of the expensive vehicles are diesel

# %% [markdown]
# #### LINE PLOT: YEAR OF MGF VS PRICE

# %%
plt.title("YEAR OF MANUFACTURE VS PRICE")
sns.lineplot(x="year",y="Price",data=df)
plt.xlim(2000,2020)
plt.show()

# %%
df["year"].corr(df["Price"])
# Out:
# 0.27432733667956716

# %% [markdown]
# * New vehicles have more higher cost

# %% [markdown]
# ### FEATURE ENGINEERING
# 1. Removal of constant feature
# 2. Creating new Features
# 3. Feature transformation
# 4. Data Reduction
# 5. Feature scaling

# %% [markdown]
# #### CREATING SOME MENINGFUL FEATURES

# %%
# Creating a binary column for petrol and diesel
df["Petrol"] = [0] * len(df)
df["Diesel"] = [0] * len(df)

for i in range(len(df)):
    if df["fuel_type"].iloc[i] == "Petrol":
        df["Petrol"].iloc[i] = 1
    elif df["fuel_type"].iloc[i] == "Diesel":
        df["Diesel"].iloc[i] = 1

# %%
# creating the age of the vehicle using the manufacturing data 
df["Age"] = 2019 - df["year"]

# %%
# binary feature whether the vehicle is driven less than 20000 or not 
df["less_driven"] = [0] * len(df)

for i in range(len(df)):
    if df["kms_driven"].iloc[i] <= 20000:
        df["less_driven"].iloc[i] = 1

# %%
df["less_driven"].value_counts()
# Out:
# 0    726
# 1    166
# Name: less_driven, dtype: int64

# %%
# Creating a feature(binary) for whether the brand is laxuary or not 
laxuary_car_company = ["Mercedes","BMW","Mini","Audi","Jaguar","Mitsubishi","Volvo"]
df["Laxuary company"] = [0] * len(df)

for i in range(len(df)):
    if df["company"].iloc[i] in laxuary_car_company:
         df["Laxuary company"].iloc[i] = 1

# %%
df["New Car"] = [0] *len(df)

for i in range(len(df)):
    if df["Age"].iloc[i] <= 6:
        df["New Car"].iloc[i] = 1

# %% [markdown]
# * Now the data is preprocessed ready for training

# %% [markdown]
# #### CORELATION MATRIX

# %%
# Corelation Matrix
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(),annot=True,cbar=True,linewidth=0.3,fmt="0.2f")
plt.title("HEAT MAP: CORELATION MATRIX")
plt.show()

# %% [markdown]
# * Multicolinear features are diesel and petrol,Age and Year

# %%
# Removing the outlier 
df = df[df["Price"] < 6000000]

# %%
df["name"].head()
# Out:
# 0      Hyundai Santro Xing XO eRLX Euro III
# 1                   Mahindra Jeep CL550 MDI
# 2                Maruti Suzuki Alto 800 Vxi
# 3    Hyundai Grand i10 Magna 1.2 Kappa VTVT
# 4          Ford EcoSport Titanium 1.5L TDCi
# Name: name, dtype: object

# %%
df["name"] = df["name"].str.split().str.slice(0,3).str.join(" ")

# %%
df["name"].nunique()
# Out:
# 303

# %% [markdown]
# #### DATA TRANSFOMATION

# %%
# Encoding name,company_name,fuel_type using the dictionary 
dict_name = dict()
i = 1
for uni_value in df["name"].unique():
    dict_name[uni_value] = i
    i += 1

dict_company = dict()
i = 1
for uni_value in df["company"].unique():
    dict_company[uni_value] = i
    i += 1

dict_fueltype = dict()
i = 1
for uni_value in df["fuel_type"].unique():
    dict_fueltype[uni_value] = i
    i += 1

# %%
dict_name
# Out:
# {'Hyundai Santro Xing': 1,
#  'Mahindra Jeep CL550': 2,
#  'Maruti Suzuki Alto': 3,
#  'Hyundai Grand i10': 4,
#  'Ford EcoSport Titanium': 5,
#  'Ford Figo': 6,
#  'Hyundai Eon': 7,
#  'Ford EcoSport Ambiente': 8,
#  'Skoda Fabia Classic': 9,
#  'Maruti Suzuki Stingray': 10,
#  'Hyundai Elite i20': 11,
#  'Mahindra Scorpio SLE': 12,
#  'Audi A8': 13,
#  'Audi Q7': 14,
#  'Mahindra Scorpio S10': 15,
#  'Hyundai i20 Sportz': 16,
#  'Maruti Suzuki Vitara': 17,
#  'Mahindra Bolero DI': 18,
#  'Maruti Suzuki Swift': 19,
#  'Maruti Suzuki Wagon': 20,
#  'Toyota Innova 2.0': 21,
#  'Renault Lodgy 85': 22,
#  'Skoda Yeti Ambition': 23,
#  'Maruti Suzuki Baleno': 24,
#  'Renault Duster 110': 25,
#  'Renault Duster 85': 26,
#  'Honda City 1.5': 27,
#  'Maruti Suzuki Dzire': 28,
#  'Honda Amaze': 29,
#  'Honda Amaze 1.5': 30,
#  'Honda City': 31,
#  'Datsun Redi GO': 32,
#  'Maruti Suzuki SX4': 33,
#  'Mitsubishi Pajero Sport': 34,
#  'Honda City ZX': 35,
#  'Tata Indigo eCS': 36,
#  'Volkswagen Polo Highline': 37,
#  'I want to': 38,
#  'Chevrolet Spark LS': 39,
#  'Renault Duster 110PS': 40,
#  'Mini Cooper S': 41,
#  'Skoda Fabia 1.2L': 42,
#  'Renault Duster': 43,
#  'Mahindra Scorpio S4': 44,
#  'Mahindra Scorpio VLX': 45,
#  'Mahindra Quanto C8': 46,
#  'Ford EcoSport': 47,
#  'Honda Brio': 48,
#  'Volkswagen Vento Highline': 49,
#  'Hyundai i20 Magna': 50,
#  'Toyota Corolla Altis': 51,
#  'Hyundai Verna Transform': 52,
#  'BMW 3 Series': 53,
#  'Maruti Suzuki A': 54,
#  'Toyota Etios GD': 55,
#  'Ford Figo Diesel': 56,
#  'Chevrolet Beat LT': 57,
#  'BMW 7 Series': 58,
#  'Mahindra XUV500 W8': 59,
#  'Hyundai i10 Magna': 60,
#  'Hyundai Verna Fluidic': 61,
#  'Maruti Suzuki Ertiga': 62,
#  'Honda Amaze 1.2': 63,
#  'Hyundai i20 Asta': 64,
#  'Maruti Suzuki Eeco': 65,
#  'Maruti Suzuki Esteem': 66,
#  'Maruti Suzuki Ritz': 67,
#  'Toyota Etios Liva': 68,
#  'Chevrolet Spark': 69,
#  'Nissan Micra XV': 70,
#  'Chevrolet Beat': 71,
#  'Toyota Corolla': 72,
#  'Ford EcoSport Trend': 73,
#  'Tata Indica V2': 74,
#  'Hindustan Motors Ambassador': 75,
#  'Toyota Innova 2.5': 76,
#  'Volkswagen Jetta Highline': 77,
#  'Volkswagen Polo Comfortline': 78,
#  'Volkswagen Polo': 79,
#  'Mahindra Scorpio': 80,
#  'Nissan Sunny': 81,
#  'Renault Kwid': 82,
#  'Chevrolet Spark LT': 83,
#  'Fiat Punto Emotion': 84,
#  'Hyundai i10 Sportz': 85,
#  'Chevrolet Beat LS': 86,
#  'Tata Indigo CS': 87,
#  'Hyundai Eon Era': 88,
#  'Mahindra XUV500': 89,
#  'Ford Fiesta': 90,
#  'Hyundai i20': 91,
#  'Hyundai Fluidic Verna': 92,
#  'Commercial , DZire': 93,
#  'Fiat Petra ELX': 94,
#  'Maruti Suzuki Ciaz': 95,
#  'Maruti Suzuki Zen': 96,
#  'Hyundai Creta 1.6': 97,
#  'Tata indigo ecs': 98,
#  'Mahindra Scorpio SLX': 99,
#  'Tata Nano Cx': 100,
#  'Tata Sumo Victa': 101,
#  'MARUTI SUZUKI DESI': 102,
#  'Volkswagen Passat Diesel': 103,
#  'Renault Scala RxL': 104,
#  'Hyundai i20 Active': 105,
#  'Mahindra Xylo E4': 106,
#  'Mahindra Jeep MM': 107,
#  'Mahindra Bolero SLE': 108,
#  'Force Motors Force': 109,
#  'Toyota Etios': 110,
#  'Honda City VX': 111,
#  'Mahindra Thar CRDe': 112,
#  'Audi A4 1.8': 113,
#  'Mercedes Benz GLA': 114,
#  'Land Rover Freelander': 115,
#  'Renault Kwid RXT': 116,
#  'Tata Aria Pleasure': 117,
#  'Mercedes Benz B': 118,
#  'Datsun GO T': 119,
#  'Honda Jazz VX': 120,
#  'Chevrolet Tavera Neo': 121,
#  'Hyundai Eon Sportz': 122,
#  'Tata Sumo Gold': 123,
#  'Chevrolet Enjoy 1.4': 124,
#  'Nissan Terrano XL': 125,
#  'Maruti Suzuki Maruti': 126,
#  'Renault Kwid 1.0': 127,
#  'Hyundai Accent GLX': 128,
#  'Yama': 129,
#  'Mahindra TUV300 T4': 130,
#  'Tata Indica eV2': 131,
#  'Honda Accord': 132,
#  'Mahindra Scorpio 2.6': 133,
#  'Honda Mobilio': 134,
#  'Skoda Laura': 135,
#  'Tata Manza Aura': 136,
#  'Chevrolet Sail UVA': 137,
#  'Audi A4 2.0': 138,
#  'Hyundai Elantra SX': 139,
#  'Mahindra KUV100 K8': 140,
#  'Hyundai i10': 141,
#  'Hyundai Accent': 142,
#  'Hyundai Verna': 143,
#  'Toyota Fortuner': 144,
#  'Mahindra Bolero Power': 145,
#  'selling car Ta': 146,
#  'Tata Zest 90': 147,
#  'Skoda Rapid Elegance': 148,
#  'Tata Vista Quadrajet': 149,
#  'Chevrolet Beat Diesel': 150,
#  'Hyundai Verna 1.4': 151,
#  'Maruti Suzuki Versa': 152,
#  'Tata Indigo LX': 153,
#  'Volkswagen Vento Konekt': 154,
#  'Mercedes Benz C': 155,
#  'URJE': 156,
#  'Maruti Suzuki Omni': 157,
#  'Hyundai Sonata Transform': 158,
#  'Honda Jazz S': 159,
#  'Mahindra Scorpio W': 160,
#  'Swift Dzire Tour': 161,
#  'Honda Brio V': 162,
#  'Mahindra TUV300 T8': 163,
#  'Nissan X Trail': 164,
#  'Ford Ikon 1.3': 165,
#  'Toyota Fortuner 3.0': 166,
#  'Tata Manza ELAN': 167,
#  'Tata zest x': 168,
#  'Mahindra xyl': 169,
#  'Mercedes Benz A': 170,
#  'Tata Indigo LS': 171,
#  'Used Commercial Maruti': 172,
#  'Hyundai Verna 1.6': 173,
#  'BMW 5 Series': 174,
#  'Skoda Superb 1.8': 175,
#  'Audi Q3 2.0': 176,
#  'Ford Figo Duratorq': 177,
#  'Mahindra Logan Diesel': 178,
#  'Tata Nano GenX': 179,
#  'Honda City SV': 180,
#  'Ford Figo Petrol': 181,
#  'Toyota Corolla H2': 182,
#  'Hyundai Xcent Base': 183,
#  'Hyundai Accent Executive': 184,
#  'Tata Zest XE': 185,
#  'Mahindra XUV500 W6': 186,
#  'Tata Tigor Revotron': 187,
#  'Maruti Suzuki 800': 188,
#  'Honda Mobilio S': 189,
#  'Tata Indica': 190,
#  'Honda Brio VX': 191,
#  'Tata Nano Lx': 192,
#  'Jaguar XE XE': 193,
#  'Hyundai Xcent S': 194,
#  'Hyundai Eon Magna': 195,
#  'Hyundai Eon D': 196,
#  'Maruti Suzuki Estilo': 197,
#  'Mahindra Scorpio Vlx': 198,
#  'Mitsubishi Lancer 1.8': 199,
#  'Ford Fiesta SXi': 200,
#  'Audi A6 2.0': 201,
#  'Hyundai Getz Prime': 202,
#  'Hyundai Santro': 203,
#  'Chevrolet Beat PS': 204,
#  'BMW X1 xDrive20d': 205,
#  'Tata Nano': 206,
#  'Chevrolet Cruze LTZ': 207,
#  'Hyun': 208,
#  'Mahindra XUV500 W10': 209,
#  'Hyundai Accent GLE': 210,
#  'Force Motors One': 211,
#  'Datsun Go Plus': 212,
#  'Chevrolet Spark 1.0': 213,
#  'Renault Duster 85PS': 214,
#  'Chevrolet Enjoy': 215,
#  'Jeep Wrangler Unlimited': 216,
#  'Hyundai Verna VGT': 217,
#  'Maruti Suzuki Celerio': 218,
#  'Tata Zest Quadrajet': 219,
#  'Hyundai i10 Era': 220,
#  'Tata Indigo Marina': 221,
#  'Commercial Chevrolet Sail': 222,
#  'Hyundai Xcent SX': 223,
#  'Tata Nano LX': 224,
#  'Commercial Car Ta': 225,
#  'tata Indica': 226,
#  'Mahindra Xylo E8': 227,
#  'Tata Manza Aqua': 228,
#  'Used bt new': 229,
#  'Sale tata': 230,
#  'Tata Venture EX': 231,
#  'Skoda Octavia Classic': 232,
#  'Tata indigo 2017': 233,
#  'Ford Ikon 1.6': 234,
#  'Tata indigo': 235,
#  'Nissan Sunny XL': 236,
#  'very good condition': 237,
#  'Sale Hyundai xcent': 238,
#  'Volkswagen Polo Trendline': 239,
#  'Hyundai Elantra 1.8': 240,
#  'Jaguar XF 2.2': 241,
#  'Audi Q5 2.0': 242,
#  'BMW X1 sDrive20d': 243,
#  'Maruti Suzuki S': 244,
#  'Volkswagen Vento Comfortline': 245,
#  'Mahindra KUV100': 246,
#  'Volkswagen Jetta Comfortline': 247,
#  'Volvo S80 Summum': 248,
#  'BMW X1': 249,
#  'Renault Duster RxL': 250,
#  'Honda WR V': 251,
#  'Mahindra Scorpio LX': 252,
#  'Audi A3 Cabriolet': 253,
#  'Hyundai Santro AE': 254,
#  'i want sale': 255,
#  'Tata ZEST 6': 256,
#  'Mahindra Xylo D2': 257,
#  'Hyundai Getz GLE': 258,
#  'Nissan Micra XL': 259,
#  'MARUTI SUZUKI ERTIGA': 260,
#  'Chevrolet Tavera LS': 261,
#  'Tata Tiago Revotron': 262,
#  'Tata Tiago Revotorq': 263,
#  'Tata Nexon': 264,
#  'Tata': 265,
#  'Ford Fusion 1.4': 266,
#  'Fiat Linea Emotion': 267,
#  'Tata Sumo Grande': 268,
#  'Volkswagen Polo Highline1.2L': 269,
#  '2012 Tata Sumo': 270,
#  'Well mentained Tata': 271,
#  'all paper updated': 272,
#  'Maruti Ertiga showroom': 273,
#  '7 SEATER MAHINDRA': 274,
#  '9 SEATER MAHINDRA': 275,
#  'scratch less Tata': 276,
#  'Maruti Suzuki swift': 277,
#  'Commercial Chevrolet beat': 278,
#  'urgent sell my': 279,
#  'sell my car': 280,
#  'Hyunda': 281,
#  'Commercial Maruti Suzuki': 282,
#  'urgent sale Ta': 283,
#  'tata': 284,
#  'TATA INDI': 285,
#  'Hyundai Creta': 286,
#  'Tata Bolt XM': 287,
#  'Hyundai Venue': 288,
#  'Renault Lodgy': 289,
#  'Ford Endeavor 4x4': 290,
#  'Any type car': 291,
#  'Mahindra Logan': 292,
#  'Chevrolet Sail 1.2': 293,
#  'Tata Manza': 294,
#  'Toyota Etios G': 295,
#  'Toyota Qualis': 296,
#  'Mahindra Quanto C4': 297,
#  'Hyundai i20 Select': 298,
#  'Hyundai Getz': 299,
#  'Skoda Fabia': 300,
#  'tata zest 2017': 301,
#  'Ta': 302,
#  'Tata Zest XM': 303}

# %%
dict_company
# Out:
# {'Hyundai': 1,
#  'Mahindra': 2,
#  'Maruti': 3,
#  'Ford': 4,
#  'Skoda': 5,
#  'Audi': 6,
#  'Toyota': 7,
#  'Renault': 8,
#  'Honda': 9,
#  'Datsun': 10,
#  'Mitsubishi': 11,
#  'Tata': 12,
#  'Volkswagen': 13,
#  'Noise': 14,
#  'Chevrolet': 15,
#  'Mini': 16,
#  'BMW': 17,
#  'Nissan': 18,
#  'Hindustan': 19,
#  'Fiat': 20,
#  'Commercial': 21,
#  'Force': 22,
#  'Mercedes': 23,
#  'Land': 24,
#  'Yamaha': 25,
#  'Swift': 26,
#  'Jaguar': 27,
#  'Jeep': 28,
#  'tata': 29,
#  'Volvo': 30,
#  'TATA': 31,
#  'Tara': 32}

# %%
dict_fueltype
# Out:
# {'Petrol': 1, 'Diesel': 2, 'Unknown': 3, 'LPG': 4}

# %%
# Encoding the categorical features 
df["company"] = df["company"].map(dict_company)
df["name"] = df["name"].map(dict_name)
df["fuel_type"] = df["fuel_type"].map(dict_fueltype)

# %%
df.drop(columns=["Age","Petrol","fuel_type","less_driven"],inplace=True)

# %% [markdown]
# #### TRAINING OF THE MODEL

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import make_pipeline
from sklearn.metrics import r2_score

X = df.drop(columns=["Price"])
y = df["Price"]

# Splitting the dataset into training and testing sets (80% train, 20% test)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=540)

# Define the degree of polynomial you want to use
degree = 2  # You can adjust this as needed

# Creating a pipeline for polynomial regression
model = make_pipeline(PolynomialFeatures(degree), LinearRegression())


# Training the polynomial regression model
model.fit(X_train, y_train)

# Saving the model 
with open('car_prediction_model.pkl','wb') as file:
    pickle.dump(model,file)


# Predicting on the test set
y_pred = model.predict(X_test)

# Evaluating the model using R^2 score
r2 = r2_score(y_test, y_pred)
print("R^2 Score:", r2)
# Out:
# R^2 Score: 0.7462662488200509

# %% [markdown]
# #### PREDICTION SYSTEM

# %%
name = input("NAME OF CAR: ")
company = input("COMPANY NAME: ")
kms_driven = int(input("KMS DRIVEN: "))
year = int(input("YEAR: "))
fuel_type = input("FUEL TYPE: ")
diesel_binary = 0
laxuary_company = 0
new_car = 0
name_encoded = dict_name[name]
company_encoded = dict_company[company]

if fuel_type == "Diesel":
    diesel_binary = 1
if company in laxuary_car_company:
    laxuary_company = 1
if kms_driven <= 20000:
    new_car = 1
    
#prediction based on the value 
predicted_value = model.predict([[name_encoded,company_encoded,year,kms_driven,diesel_binary,laxuary_company,new_car]])
    
print("Model Predicted Value: ",predicted_value)
# Out:
# NAME OF CAR: Hyundai i20 Select
# COMPANY NAME: Hyundai
# KMS DRIVEN: 20000
# YEAR: 2015
# FUEL TYPE: Diesel
# Model Predicted Value:  [724973.99797344]

# %% [markdown]
# - Actual price was 20,00,000 so , our model is working well
